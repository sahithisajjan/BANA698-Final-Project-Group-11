# %% [markdown]
# # 02 — Feature Engineering (Construct Building)
#
# Goal:
# - Load the baseline dataset from `Data/processed/`
# - Create engineered features / constructs needed for our research questions
# - Save a new feature-ready dataset for modeling
